# %% [markdown]
# # Strings:

# %%
s='Hello'
s=" it's hello"
s='''Hello'''       #use for multiline string...
s="""Hello"""       #use for multiline string...
print(s)
# Out:
# Hello
# Hello

# %% [markdown]
# # how to access:

# %%
# posotive indexing:
a='Hello world'
print(a[1])
# Out:
# e

# %%
# negative indexing:
a='Hello world'
print(a[-1])
# Out:
# d

# %%
#Slicing:
print(a[0:5])
# Out:
# Hello

# %%
print(a[::-1])
# Out:
# dlrow olleH

# %%
print(a[0:9:2])
# Out:
# Hlowr

# %%
a='Hello world'
print(a[-1:-6:-1])
# Out:
# dlrow

# %% [markdown]
# # Editing & Deleting in strings:

# %%
# editing:
a
s[0]='H'
# strings are immutable, so we can't change them.....
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7436\3145441213.py in <module>
#       1 a
# ----> 2 s[0]='H'
#
# TypeError: 'str' object does not support item assignment

# %%
# Deletion:
a
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7436\855703155.py in <module>
# ----> 1 a
#       2 del a
#       3 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# # some operation on strings:

# %%
#Airthematic
#Relational
#Logical
#Loops on strings
#Membership

# %%
#Airthematic just +,*:
print("Hello"+"World")
print("Hello"*3)
# Out:
# HelloWorld
# HelloHelloHello

# %%
#Relational:
print('Hello'=='Hello')
print('Hello'!='Hello')
# Out:
# True
# False
# False
# False

# %%
print('Hello'>'Hello')
print('Hello'<'Hello')
#lexographically..
# Out:
# False
# False

# %%
print('Hello' and 'world')
print('Hello' or 'world')
print(not 'world')
# Out:
# world
# Hello
# False

# %%
#loops on string:
for i in 'Hello':
    print(i)
# Out:
# H
# e
# l
# l
# o

# %%
for i in 'lahore':
    print('MDK')
# Out:
# MDK
# MDK
# MDK
# MDK
# MDK
# MDK

# %%
#Membership:
a='Hello'
'h' in  a
# Out:
# False

# %% [markdown]
# #  Common Functions:

# %%
#lenght:
a='Hello'
len(a)
# Out:
# 5

# %%
#Maximum
a='Hello'
max(a)
# Out:
# 'o'

# %%
#Minimum:
a='Hello'
min(a)
# Out:
# 'H'

# %%
#sorted:
a='Hello'
sorted(a)
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
a='Hello'
sorted(a,reverse=True)
# Out:
# ['o', 'l', 'l', 'e', 'H']

# %% [markdown]
# # Specific Functions:

# %%
#Capitalize:
a='hello world'
a.capitalize()
# Out:
# 'Hello world'

# %%
a.title()
# Out:
# 'Hello World'

# %%
a.upper()
# Out:
# 'HELLO WORLD'

# %%
a='HELLO'
a.lower()
# Out:
# 'hello'

# %%
'Hello World'.swapcase()
# Out:
# 'hELLO wORLD'

# %%
#count:
'my name is awais'.count('i')
# Out:
# 2

# %%
#Find:
'my name is awais'.find('is')
# Out:
# 8

# %%
'my name is awais'.find('x')
# Out:
# -1

# %%
#Index:
'my name is awais'.index('is')
# Out:
# 8

# %%
'my name is awais'.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7436\2021260003.py in <module>
# ----> 1 'my name is awais'.index('x')
#
# ValueError: substring not found

# %%
#endswith:
'my name is awais'.endswith('is')
# Out:
# True

# %%
#startswith:
'my name is awais'.startswith('is')
# Out:
# False

# %%
#Format:
name='Awais'
gender='male'
'Hi! my name is {} and i am a {}'.format(name,gender)
# Out:
# 'Hi! my name is Awais and i am a male'

# %%
#isalnum:
'Awais123'.isalnum()
# Out:
# True

# %%
#isalpha:
'Awais'.isalpha()
# Out:
# True

# %%
#isdigit:
'123'.isdigit()
# Out:
# False

# %%
#isidentifer:
'name'.isidentifier()
# Out:
# True

# %%
'1name'.isidentifier()
# Out:
# False

# %%
#Split:
'Hi my name is Awais'.split()
# Out:
# ['Hi', 'my', 'name', 'is', 'Awais']

# %%
'Hi my name is Awais'.split('is')
# Out:
# ['Hi my name ', ' Awa', '']

# %%
#join:
" ".join(['Hi', 'my', 'name', 'is', 'Awais'])
# Out:
# 'Hi my name is Awais'

# %%
#Replace:
'Hi my name is Awais'.replace('Awais','Anas')
# Out:
# 'Hi my name is Anas'

# %%
#Strip:
'Awais                   '.strip()
# Out:
# 'Awais'

# %%
# Find the lenght of the string without using len() func:

s=input("Enter the string")

counter=0

for i in s:
    print(i)
    counter+=1
print("lenght of string is",counter)
# Out:
# Enter the stringhello
# h
# e
# l
# l
# o
# lenght of string is 5

# %%
# Extrct username from a given email:

s=input("Enter the email")
pos= s.index("@")
print(s[0:5])
# Out:
# Enter the emailawais@gmail.com
# awais

# %%
#count the fequency of a particular char in a provided string:

s=input("Enter the string: ")

term=input("what would you like to search for: ")
counter=0
for i in s:
    if i==term:
        counter+=1
        
print("Frequency",counter)
# Out:
# Enter the string: Hi How are You
# what would you like to search for: o
# Frequency 2

# %%
# write a program which can remove a particular character from a string:

s= input("Enter the string")
term=input("What would you like to remove")

result=''

for i in s:
    if i!=term:
        result=result+i
print(result)
# Out:
# Enter the stringawais
# What would you like to removei
# awas

# %%
# write a program that can check whether a given string is palindrome or not:
#A palindrome is a string that reads the same forwards and backwards..

s= input("Enter the string: ")

flag = True
for i in range(0,len(s)//2):
    
    if s[i] != s[len(s)- i - 1]:
        flag= False 
        print("Not a palindrome")
        break
if flag:
    print("palindrome")
# Out:
# Enter the string: civic
# palindrome

# %%
# to count the number of the string without using split():

s= input("Enter the string")

L=[]
temp=''
for i in s:
    if i!=' ':
        temp=temp+i
    else:
        L.append(temp)
        temp=' '
L.append(temp)        
print(L)
# Out:
# Enter the stringhello how are you
# ['hello', ' how', ' are', ' you']

# %%
# to convert a string to title case without using title():

s=input("Enter the string")
L=[]
for i in s.split():
    L.append(i[0].upper() +i[1:].lower())
    
print(' '. join(L))
# Out:
# Enter the stringhello how are you
# Hello How Are You

# %%
# to convert an integer to string:

number= int(input("Enter the number"))

digits='0123456789'
result=''
while number!=0:
    result= digits[number %10] +result
    number= number//10
print(result)
print(type(result))
# Out:
# Enter the number0
#
# <class 'str'>
