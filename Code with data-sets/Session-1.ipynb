# %% [markdown]
# # Print Functions:

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(7)
# Out:
# 7

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print('Hello',1,2.3,True)
# Out:
# Hello 1 2.3 True

# %%
print('Hello',1,2.3,True,sep='/')
# Out:
# Hello/1/2.3/True

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello",end='-')
print("World")
# Out:
# Hello-World

# %% [markdown]
# # Data Types:

# %%
#Integers:


print(8)
print(1e309)
# Out:
# 8
# inf

# %%
#Decimal/Float:
print(1.22)
print(1.7e309)
# Out:
# 1.22
# inf

# %%
#Boolean:
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String:
print("hello world")
# Out:
# hello world

# %%
#Complex Numbers:
print(5+6j)
# Out:
# (5+6j)

# %%
#List:
print([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Tuple:
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#Sets:
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary:
print({"Name","Awais",'gender','male'})
# Out:
# {'male', 'Name', 'Awais', 'gender'}

# %%
#Type:
type(7)
type('hello')
type(True)
type(8.5)
#type tell us every data type....
# Out:
# float

# %% [markdown]
# # Variables:

# %%
#how to creat variable:

n='Hello'
print(n)
# Out:
# Hello

# %%
a,b,c=1,2,3
print(b)
# Out:
# 2

# %%
a=b=c=10
print(b)
# Out:
# 10

# %%
a=4
b=5
print(a+b)
# Out:
# 9

# %%
#Dynamic typing.
#Static typing.
#Dynamic Binding.
#Static Binding.

# %%
#Take 2 no. and add them...
u1=int(input())
u2=int(input())
print(u1+u2)
# Out:
# 1
# 2
# 3

# %%
#Keywords:Python keywords are special reserved words that have specific 
#meanings and purposes and can't be used for anything but those specific purposes...

# %%
#Identifires:the name we give to identify a variable, function, class, module or other object.
#you can't start with digit.
1name='awais'
# Out:
#   File "C:\Users\TECH DEALS\AppData\Local\Temp\ipykernel_11756\149602330.py", line 3
#     1name='awais'
#      ^
# SyntaxError: invalid syntax

# %%
name1='Awais'
print(name1)
# Out:
# Awais

# %%
#you can not use special character as identifers except _.. ...
first_name=4
print(first_name)
# Out:
# 4

# %%
first-name=10
print(first-name)
# Out:
#   File "C:\Users\TECH DEALS\AppData\Local\Temp\ipykernel_11756\1621277030.py", line 1
#     first-name=10
#     ^
# SyntaxError: cannot assign to operator

# %%
#Identifiers can't be keywords.

# %% [markdown]
# # Taske:

# %%
#Take 2 no. and add them...
u1=int(input('1st Number:'))
u2=int(input('2nd Number:'))
r=u1+u2
print(r)
# Out:
# 1st Number:3
# 2nd Number:4
# 7

# %%
# Explicit type convertion:users convert the data type of an object to required data type...  
int(5.4)
# Out:
#   File "C:\Users\TECH DEALS\AppData\Local\Temp\ipykernel_11756\4284846026.py", line 1
#     Explicit type convertion:users convert the data type of an object to required data type...
#              ^
# SyntaxError: invalid syntax

# %%
# Implicit type convertion:when the data type conversion takes place during compilation or during the runtime..

# %%
str(5)
# Out:
# '5'

# %% [markdown]
# # Literals:

# %%
#literals are a data type and can hold any value type, such as strings, numbers, and more.
a=2
#where 2 is literals..

# %%
a=0b1010 #Binary literal
b=100    #Decimail literal
c=0o310  #Octal lieral
d=0x12c  #Hexadecimal literal
# Out:
# 10

# %%
#Float literals:
f1=10.5
f2=1.5e3     #1.5 *10^2
f3=1.5e-3    #1.5 * 10^-3

# %%
#Complex Literals:
x=3.14j
print(x.real,x.imag,sep=',')
# Out:
# 0.0,3.14

# %% [markdown]
# # How to asign values to string:

# %%
string='Hello'
strings="Hello"
char="c"
multiline_str="""This multiline string"""
unicod=u"\U0001f60001f606\U0001F923"
raw_str=r"raw \n string"

# %%
unicode=u"\U0001f600\U0001F606\U0001F923"
print(unicode)
# Out:
# 😀😆🤣

# %%
raw_str=r"raw \n string"
print(raw_str)
# Out:
# raw \n string

# %% [markdown]
# # Boolean:

# %%
#True =1, False=0...
a=True+4
b=False+10
print('a:',a)
print('b:',b)
# Out:
# a: 5
# b: 10

# %%
#none
a=None
print(a)
#There is no variable decleration in python,so use None to use variable in future...
# Out:
# None
